# %% [markdown]
# # Introduction
# In this project, we will explore a data set of 50,000 data points to analyze the statistics of an Ebay section available in Germany that sell used cars. The skills involved in this project are cleaning and analyzing data using numpy and pandas libraries.

# %%
import numpy as np
import pandas as pd
autos = pd.read_csv("autos.csv", encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# # Observations
# There are 20 columns with 5 of integer values and the rests are strings. There are 50,000 rows.
#
# Some columns contain null values but none of them have more than 20% of null values

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
#renaming the columns
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gear_box', 'power_PS', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#     gear_box  power_PS   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# # Explanation for above changes
# The changes made above were converting camel case to snake case and add underscore to indicate spaces to make the columns much easier to understand.

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-30 17:37:35  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year gear_box      power_PS  model  \
# ...

# %% [markdown]
# # Summary
# The columns that have mostly one value that are candidates for dropping are seller, offer_type, gear_box and un_repaired_damage.
# The rest deserve more investigations and columns with numeric data stored as texts are price and odometer.

# %%
autos["price"]
# Out:
# 0         $5,000
# 1         $8,500
# 2         $8,990
# 3         $4,350
# 4         $1,350
# 5         $7,900
# 6           $300
# 7         $1,990
# 8           $250
# 9           $590
# 10          $999
# 11          $350
# 12        $5,299
# 13        $1,350
# 14        $3,999
# 15       $18,900
# 16          $350
# 17        $5,500
# 18          $300
# 19        $4,150
# 20        $3,500
# 21       $41,500
# 22       $25,450
# 23        $7,999
# 24       $48,500
# 25           $90
# 26          $777
# 27            $0
# 28        $5,250
# 29        $4,999
#           ...
# 49970    $15,800
# 49971       $950
# 49972     $3,300
# 49973     $6,000
# 49974         $0
# 49975     $9,700
# 49976     $5,900
# 49977     $5,500
# 49978       $900
# 49979    $11,000
# 49980       $400
# 49981     $2,000
# 49982     $1,950
# 49983       $600
# 49984         $0
# 49985     $1,000
# 49986    $15,900
# 49987    $21,990
# 49988     $9,550
# 49989       $150
# 49990    $17,500
# ...

# %%
autos["price"] = (autos["price"].str.replace("$","")
                  .str.replace(",","")
                  .astype(float))

# %%
autos["odometer"]
# Out:
# 0        150,000km
# 1        150,000km
# 2         70,000km
# 3         70,000km
# 4        150,000km
# 5        150,000km
# 6        150,000km
# 7        150,000km
# 8        150,000km
# 9        150,000km
# 10       150,000km
# 11       150,000km
# 12        50,000km
# 13       150,000km
# 14       150,000km
# 15        80,000km
# 16       150,000km
# 17       150,000km
# 18       150,000km
# 19       150,000km
# 20       150,000km
# 21       150,000km
# 22        10,000km
# 23       150,000km
# 24        30,000km
# 25       150,000km
# 26       125,000km
# 27       150,000km
# 28       150,000km
# 29       150,000km
#            ...
# 49970     60,000km
# 49971    150,000km
# 49972    150,000km
# 49973    150,000km
# 49974    150,000km
# 49975    100,000km
# 49976    150,000km
# 49977    150,000km
# 49978    150,000km
# 49979     70,000km
# 49980    125,000km
# 49981    150,000km
# 49982     90,000km
# 49983    150,000km
# 49984    150,000km
# 49985    150,000km
# ...

# %%
autos["odometer"] = (autos["odometer"].str.replace("km","")
                  .str.replace(",","")
                  .astype(float))

# %%
autos.rename(columns={"odometer":"odometer_km"}, inplace=True)

# %%
autos["price"].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos["price"].value_counts()
# Out:
# 0.0           1421
# 500.0          781
# 1500.0         734
# 2500.0         643
# 1200.0         639
# 1000.0         639
# 600.0          531
# 800.0          498
# 3500.0         498
# 2000.0         460
# 999.0          434
# 750.0          433
# 900.0          420
# 650.0          419
# 850.0          410
# 700.0          395
# 4500.0         394
# 300.0          384
# 2200.0         382
# 950.0          379
# 1100.0         376
# 1300.0         371
# 3000.0         365
# 550.0          356
# 1800.0         355
# 5500.0         340
# 1250.0         335
# 350.0          335
# 1600.0         327
# 1999.0         322
#               ...
# 2225.0           1
# 69997.0          1
# 139997.0         1
# 69999.0          1
# 4780.0           1
# 8930.0           1
# 21599.0          1
# 15911.0          1
# 10000000.0       1
# 5180.0           1
# 919.0            1
# 1247.0           1
# 5998.0           1
# 27020.0          1
# 21888.0          1
# 46500.0          1
# ...

# %%
autos["odometer_km"].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos["date_crawled"].str[:10].value_counts(normalize=True,dropna=False).sort_index()
# Out:
# 2016-03-05    0.02538
# 2016-03-06    0.01394
# 2016-03-07    0.03596
# 2016-03-08    0.03330
# 2016-03-09    0.03322
# 2016-03-10    0.03212
# 2016-03-11    0.03248
# 2016-03-12    0.03678
# 2016-03-13    0.01556
# 2016-03-14    0.03662
# 2016-03-15    0.03398
# 2016-03-16    0.02950
# 2016-03-17    0.03152
# 2016-03-18    0.01306
# 2016-03-19    0.03490
# 2016-03-20    0.03782
# 2016-03-21    0.03752
# 2016-03-22    0.03294
# 2016-03-23    0.03238
# 2016-03-24    0.02910
# 2016-03-25    0.03174
# 2016-03-26    0.03248
# 2016-03-27    0.03104
# 2016-03-28    0.03484
# 2016-03-29    0.03418
# 2016-03-30    0.03362
# 2016-03-31    0.03192
# 2016-04-01    0.03380
# 2016-04-02    0.03540
# 2016-04-03    0.03868
# 2016-04-04    0.03652
# 2016-04-05    0.01310
# 2016-04-06    0.00318
# 2016-04-07    0.00142
# Name: date_crawled, dtype: float64

# %%
autos["ad_created"].str[:10].value_counts(normalize=True,dropna=False).sort_index()
# Out:
# 2015-06-11    0.00002
# 2015-08-10    0.00002
# 2015-09-09    0.00002
# 2015-11-10    0.00002
# 2015-12-05    0.00002
# 2015-12-30    0.00002
# 2016-01-03    0.00002
# 2016-01-07    0.00002
# 2016-01-10    0.00004
# 2016-01-13    0.00002
# 2016-01-14    0.00002
# 2016-01-16    0.00002
# 2016-01-22    0.00002
# 2016-01-27    0.00006
# 2016-01-29    0.00002
# 2016-02-01    0.00002
# 2016-02-02    0.00004
# 2016-02-05    0.00004
# 2016-02-07    0.00002
# 2016-02-08    0.00002
# 2016-02-09    0.00004
# 2016-02-11    0.00002
# 2016-02-12    0.00006
# 2016-02-14    0.00004
# 2016-02-16    0.00002
# 2016-02-17    0.00002
# 2016-02-18    0.00004
# 2016-02-19    0.00006
# 2016-02-20    0.00004
# 2016-02-21    0.00006
#                ...
# 2016-03-09    0.03324
# 2016-03-10    0.03186
# 2016-03-11    0.03278
# 2016-03-12    0.03662
# 2016-03-13    0.01692
# 2016-03-14    0.03522
# 2016-03-15    0.03374
# 2016-03-16    0.03000
# 2016-03-17    0.03120
# 2016-03-18    0.01372
# ...

# %%
autos["last_seen"].str[:10].value_counts(normalize=True,dropna=False).sort_index()
# Out:
# 2016-03-05    0.00108
# 2016-03-06    0.00442
# 2016-03-07    0.00536
# 2016-03-08    0.00760
# 2016-03-09    0.00986
# 2016-03-10    0.01076
# 2016-03-11    0.01252
# 2016-03-12    0.02382
# 2016-03-13    0.00898
# 2016-03-14    0.01280
# 2016-03-15    0.01588
# 2016-03-16    0.01644
# 2016-03-17    0.02792
# 2016-03-18    0.00742
# 2016-03-19    0.01574
# 2016-03-20    0.02070
# 2016-03-21    0.02074
# 2016-03-22    0.02158
# 2016-03-23    0.01858
# 2016-03-24    0.01956
# 2016-03-25    0.01920
# 2016-03-26    0.01696
# 2016-03-27    0.01602
# 2016-03-28    0.02086
# 2016-03-29    0.02234
# 2016-03-30    0.02484
# 2016-03-31    0.02384
# 2016-04-01    0.02310
# 2016-04-02    0.02490
# 2016-04-03    0.02536
# 2016-04-04    0.02462
# 2016-04-05    0.12428
# 2016-04-06    0.22100
# 2016-04-07    0.13092
# Name: last_seen, dtype: float64

# %% [markdown]
# # Exploration
# For date_crawled distribution, the distribution seems to spread out evenly but drops significantly for the last date.
#
# For ad_created distribution, the distribution seems to increases for the month of march and early april than for february.
#
# For last_seen distribution, the distribution seems significantly higher for the last 3 dates than for other dates

# %%
autos["registration_year"].value_counts(normalize=True).sort_index()
# Out:
# 1000    0.00002
# 1001    0.00002
# 1111    0.00002
# 1500    0.00002
# 1800    0.00004
# 1910    0.00018
# 1927    0.00002
# 1929    0.00002
# 1931    0.00002
# 1934    0.00004
# 1937    0.00008
# 1938    0.00002
# 1939    0.00002
# 1941    0.00004
# 1943    0.00002
# 1948    0.00002
# 1950    0.00006
# 1951    0.00004
# 1952    0.00002
# 1953    0.00002
# 1954    0.00004
# 1955    0.00004
# 1956    0.00010
# 1957    0.00004
# 1958    0.00008
# 1959    0.00014
# 1960    0.00068
# 1961    0.00012
# 1962    0.00008
# 1963    0.00018
#          ...
# 2001    0.05406
# 2002    0.05066
# 2003    0.05454
# 2004    0.05474
# 2005    0.06030
# 2006    0.05416
# 2007    0.04608
# 2008    0.04462
# 2009    0.04196
# 2010    0.03194
# 2011    0.03268
# 2012    0.02646
# 2013    0.01612
# 2014    0.01332
# 2015    0.00798
# 2016    0.02632
# 2017    0.02906
# 2018    0.00984
# 2019    0.00006
# 2800    0.00002
# 4100    0.00002
# 4500    0.00002
# 4800    0.00002
# 5000    0.00008
# ...

# %% [markdown]
# # Registration year summary
# The distribution for registration years increases during the years 2000s. There are years that are above 2016 and before 1900, we need to explore these years.

# %%
autos.loc[autos["registration_year"].between(1900,2016), "registration_year"].describe()
# Out:
# count    48028.00000
# mean      2002.80351
# std          7.31085
# min       1910.00000
# 25%       1999.00000
# 50%       2003.00000
# 75%       2008.00000
# max       2016.00000
# Name: registration_year, dtype: float64

# %% [markdown]
# The highest acceptable values is 2016 and the lowest is 2002 - 7.31*2 = 1987 because these are just 2 std away from the mean.

# %%
autos.loc[autos["registration_year"].between(1987,2016), "registration_year"].value_counts(normalize=True).sort_index()
# Out:
# 1987    0.001595
# 1988    0.003019
# 1989    0.003848
# 1990    0.008398
# 1991    0.007569
# 1992    0.008313
# 1993    0.009461
# 1994    0.014032
# 1995    0.027916
# 1996    0.030701
# 1997    0.043118
# 1998    0.052154
# 1999    0.063784
# 2000    0.071310
# 2001    0.057469
# 2002    0.053855
# 2003    0.057979
# 2004    0.058192
# 2005    0.064103
# 2006    0.057575
# 2007    0.048986
# 2008    0.047434
# 2009    0.044606
# 2010    0.033954
# 2011    0.034741
# 2012    0.028129
# 2013    0.017137
# 2014    0.014160
# 2015    0.008483
# 2016    0.027980
# Name: registration_year, dtype: float64

# %% [markdown]
# Most of the registered years cluster around 2000, give or take 5 years

# %%
autos["brand"].value_counts(normalize=True).head(20)
# Out:
# volkswagen        0.21374
# opel              0.10922
# bmw               0.10858
# mercedes_benz     0.09468
# audi              0.08566
# ford              0.06958
# renault           0.04808
# peugeot           0.02912
# fiat              0.02616
# seat              0.01882
# skoda             0.01572
# mazda             0.01514
# nissan            0.01508
# citroen           0.01402
# smart             0.01402
# toyota            0.01234
# sonstige_autos    0.01092
# hyundai           0.00976
# volvo             0.00914
# mini              0.00848
# Name: brand, dtype: float64

# %% [markdown]
# The brands that I have chosen to aggregate for are the top 20 brands listed above.

# %%
brands_mean = {}
brands = list(autos["brand"].value_counts(normalize=True,dropna=False).head(20).index)
#make the top 20 brands into a list to loop through

# %%
for brand in brands:
    brands_mean[brand] = autos.loc[autos["brand"] == brand, "price"].mean()
brands_mean
# Out:
# {'audi': 8965.560354891431,
#  'bmw': 8252.918953766808,
#  'citroen': 42657.46362339515,
#  'fiat': 12134.20642201835,
#  'ford': 7105.662546708824,
#  'hyundai': 5316.754098360656,
#  'mazda': 3962.542932628798,
#  'mercedes_benz': 29511.955428812842,
#  'mini': 10392.393867924528,
#  'nissan': 4588.879310344828,
#  'opel': 5106.092657022524,
#  'peugeot': 3010.8688186813188,
#  'renault': 2351.301996672213,
#  'seat': 4219.431455897981,
#  'skoda': 6305.044529262086,
#  'smart': 3482.971469329529,
#  'sonstige_autos': 38300.84065934066,
#  'toyota': 5097.941653160454,
#  'volkswagen': 6384.167399644428,
#  'volvo': 31689.908096280087}

# %% [markdown]
# Mercedes, sonstige_autos and citroen have the highest average price. While mazda and toyota are lowest.

# %%
mileage_mean = {}
for brand in brands:
    mileage_mean[brand] = autos.loc[autos["brand"] == brand, "odometer_km"].mean()
mileage_mean
# Out:
# {'audi': 129643.9411627364,
#  'bmw': 132521.64302818198,
#  'citroen': 119764.62196861627,
#  'fiat': 117037.4617737003,
#  'ford': 124131.93446392642,
#  'hyundai': 106782.7868852459,
#  'mazda': 125132.10039630119,
#  'mercedes_benz': 130886.14279678918,
#  'mini': 89375.0,
#  'nissan': 118978.7798408488,
#  'opel': 129298.66324848929,
#  'peugeot': 127352.33516483517,
#  'renault': 128223.79367720465,
#  'seat': 122061.63655685441,
#  'skoda': 110947.83715012722,
#  'smart': 100756.06276747503,
#  'sonstige_autos': 87188.6446886447,
#  'toyota': 115988.65478119935,
#  'volkswagen': 128955.27276129878,
#  'volvo': 138632.3851203501}

# %%
df_mean_price = pd.DataFrame(pd.Series(brands_mean), columns=["mean price"])
df_mean_mileage = pd.DataFrame(pd.Series(mileage_mean), columns=["mean mileage"])

# %%
df_mean_price
# Out:
#                   mean price
# audi             8965.560355
# bmw              8252.918954
# citroen         42657.463623
# fiat            12134.206422
# ford             7105.662547
# hyundai          5316.754098
# mazda            3962.542933
# mercedes_benz   29511.955429
# mini            10392.393868
# nissan           4588.879310
# opel             5106.092657
# peugeot          3010.868819
# renault          2351.301997
# seat             4219.431456
# skoda            6305.044529
# smart            3482.971469
# sonstige_autos  38300.840659
# toyota           5097.941653
# volkswagen       6384.167400
# volvo           31689.908096

# %%
df_mean_mileage
# Out:
#                  mean mileage
# audi            129643.941163
# bmw             132521.643028
# citroen         119764.621969
# fiat            117037.461774
# ford            124131.934464
# hyundai         106782.786885
# mazda           125132.100396
# mercedes_benz   130886.142797
# mini             89375.000000
# nissan          118978.779841
# opel            129298.663248
# peugeot         127352.335165
# renault         128223.793677
# seat            122061.636557
# skoda           110947.837150
# smart           100756.062767
# sonstige_autos   87188.644689
# toyota          115988.654781
# volkswagen      128955.272761
# volvo           138632.385120
